# %%
import matplotlib.pyplot as plt
import numpy as np

# Categories
"""categories = [
    "Whole dataset", 
    "Autos & Vehicles", 
    "Beauty & Fitness", 
    "Books & Literature", 
    "Business & Industrial"
]

# Data for F1, MAP50, and MAP15 scores
f1_audio = [55.30, 54.00, 54.28, 59.36, 53.68]
f1_visual = [55.00, 53.89, 54.78, 59.31, 54.17]
map50_audio = [57.61, 55.81, 54.95, 55.17, 55.72]
map50_visual = [57.94, 58.92, 60.42, 55.29, 57.77]
map15_audio = [24.33, 22.58, 20.71, 20.25, 23.00]
map15_visual = [24.41, 26.20, 25.02, 21.94, 24.14]
categories = [
    "Whole dataset", 
    "Computers & Electronics", 
    "Finance", 
    "Health", 
    "Food & Drink"
]

# Data for Epoch 150 at F1, MAP50, and MAP15 scores
f1_audio = [55.30, 55.88, 45.88, 61.29, 52.87]
f1_visual = [54.99, 57.14, 51.29, 60.04, 55.62]
map50_audio = [57.61, 53.45, 48.85, 63.18, 55.56]
map50_visual = [57.94, 58.42, 55.60, 62.01, 64.89]
map15_audio = [24.33, 21.11, 15.57, 29.59, 22.81]
map15_visual = [24.41, 23.27, 26.09, 24.04, 28.64]
categories = [
    "Whole dataset", 
    "Hobbies & Leisure", 
    "Home & Garden", 
    "Jobs & Education", 
    "Internet & Telecom"
]

# Data for Epoch 150 at F1, MAP50, and MAP15 scores
f1_audio = [55.30, 52.87, 51.09, 54.41, 55.31]
f1_visual = [54.99, 53.07, 53.04, 55.91, 56.17]
map50_audio = [57.61, 54.02, 54.44, 54.18, 54.08]
map50_visual = [57.94, 58.17, 61.38, 66.22, 59.43]
map15_audio = [24.33, 20.79, 21.66, 21.84, 21.58]
map15_visual = [24.41, 24.63, 26.41, 29.30, 25.64]
categories = [
    "Whole dataset", 
    "People & Society", 
    "Real Estate", 
    "Sports", 
    "Reference"
]

# Data for Epoch 150 at F1, MAP50, and MAP15 scores
f1_audio = [55.30, 59.72, 48.20, 51.63, 51.43]
f1_visual = [54.99, 63.30, 55.89, 51.82, 50.34]
map50_audio = [57.61, 56.29, 46.55, 52.88, 53.88]
map50_visual = [57.94, 59.89, 55.08, 58.26, 51.83]
map15_audio = [24.33, 23.06, 17.52, 19.62, 24.11]
map15_visual = [24.41, 27.31, 25.35, 25.31, 20.54]
categories = [
    "Whole dataset", 
    "Science", 
    "Travel", 
    "Shopping"
]

# Data for Epoch 150 at F1, MAP50, and MAP15 scores
f1_audio = [55.30, 52.30, 51.53, 54.33]
f1_visual = [54.99, 52.66, 52.75, 55.22]
map50_audio = [57.61, 53.97, 53.90, 53.68]
map50_visual = [57.94, 57.15, 56.61, 57.82]
map15_audio = [24.33, 22.16, 20.95, 21.68]
map15_visual = [24.41, 22.64, 21.62, 25.40]
categories = [
    "Whole dataset", 
    "Arts & Entertainment", 
    "Games", 
    "Pets & Animals"
]

# Data for Epoch 150 at F1, MAP50, and MAP15 scores
f1_audio = [55.30, 58.30, 54.34, 53.69]
f1_visual = [54.99, 56.20, 53.97, 51.90]
map50_audio = [57.61, 60.54, 57.46, 55.50]
map50_visual = [57.94, 56.73, 56.72, 55.55]
map15_audio = [24.33, 26.58, 25.70, 22.91]
map15_visual = [24.41, 23.11, 24.74, 23.10]
categories = [
    "Whole dataset", 
    "Law & Government", 
    "News"
]

# Data for Epoch 150 at F1, MAP50, and MAP15 scores
f1_audio = [55.30, 50.14, 48.26]
f1_visual = [54.99, 51.38, 49.937]
map50_audio = [57.61, 54.05, 54.20]
map50_visual = [57.94, 55.76, 54.062]
map15_audio = [24.33, 19.87, 23.65]
map15_visual = [24.41, 24.29, 23.178]"""
"""categories = [
    "Epoch 100", 
    "Epoch 150"
]

# Data for Law & Government at F1, MAP50, and MAP15 scores
f1_audio = [51.81, 50.14]
f1_visual = [49.48, 51.38]
map50_audio = [57.43, 54.05]
map50_visual = [53.10, 55.76]
map15_audio = [25.85, 19.87]
map15_visual = [21.58, 24.29]"""


categories = [
    "f1_visual", 
    "f1_audio",
    "map50_visual",
    "map50_audio",
    "map15_visual",
    "map15_audio"
]

# Data for F1, MAP50, and MAP15 scores
base = [52.71, 51.43, 53.86, 53.88, 22.71, 20.79]
ib1e02 = [52.93, 53.04, 53.33, 54.96, 21.39, 23.15]
ib1e06 = [54.16, 53.77, 54.23, 55.17, 22.69, 23.89]

# Bar width
width = 0.15  

"""# Set positions for each bar group
x = np.arange(len(categories))
x_positions = {
    "F1 Audio": x - 2.5 * width,
    "F1 Visual": x - 1.5 * width,
    "MAP50 Audio": x - 0.5 * width,
    "MAP50 Visual": x + 0.5 * width,
    "MAP15 Audio": x + 1.5 * width,
    "MAP15 Visual": x + 2.5 * width,
}

# Create the bar chart
plt.figure(figsize=(16, 8))
plt.bar(x_positions["F1 Audio"], f1_audio, width, label='F1 Audio', color='lightgreen')
plt.bar(x_positions["F1 Visual"], f1_visual, width, label='F1 Visual', color='lightblue')
plt.bar(x_positions["MAP50 Audio"], map50_audio, width, label='MAP50 Audio', color='green')
plt.bar(x_positions["MAP50 Visual"], map50_visual, width, label='MAP50 Visual', color='blue')
plt.bar(x_positions["MAP15 Audio"], map15_audio, width, label='MAP15 Audio', color='darkgreen')
plt.bar(x_positions["MAP15 Visual"], map15_visual, width, label='MAP15 Visual', color='darkblue')

# Add labels, title, and legend
plt.xticks(x, categories, rotation=45)
plt.ylabel('Scores')
plt.title('Comparison of Laws & Government')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Move legend outside the chart
plt.tight_layout()
plt.savefig("table/Law.png")
plt.show()"""

# Set positions for each bar group
x = np.arange(len(categories))
x_positions = {
    "base": x +1 * width,
    "ib1e-02": x +2 * width,
    "ib1e-06": x + 3 * width,
}

# Create the bar chart
plt.figure(figsize=(16, 8))
plt.bar(x_positions["base"], base, width, label='base', color='black')
plt.bar(x_positions["ib1e-02"], ib1e02, width, label='ib1e-02', color='blue')
plt.bar(x_positions["ib1e-06"], ib1e06, width, label='ib1e-06', color='green')

# Add labels, title, and legend
plt.xticks(x, categories, rotation=45)
plt.ylabel('Scores')
plt.title('Reference')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Move legend outside the chart
plt.tight_layout()
plt.savefig("table/IB/reference.png")
plt.show()
